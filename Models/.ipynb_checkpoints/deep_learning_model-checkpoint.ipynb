# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.loc[df["koi_disposition"]=="FALSE POSITIVE", "koi_disposition"] ="False_Positive"
df.koi_disposition
# Out:
# 0            CONFIRMED
# 1       False_Positive
# 2       False_Positive
# 3            CONFIRMED
# 4            CONFIRMED
#              ...
# 6986    False_Positive
# 6987    False_Positive
# 6988         CANDIDATE
# 6989    False_Positive
# 6990    False_Positive
# Name: koi_disposition, Length: 6991, dtype: object

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split
y=df["koi_disposition"]
X=df.drop(columns=["koi_disposition"])
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)
print(X.shape, y.shape)
# Out:
# (6991, 40) (6991,)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6080              1              0              0              0   12.496435
# 3001              0              0              0              0   11.615625
# 570               0              1              0              0   10.980246
# 4897              1              0              0              0  466.908240
# 625               0              1              1              1    1.061933
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6080     2.213000e-04    -2.213000e-04   132.035800          0.014300
# 3001     1.528000e-04    -1.528000e-04   131.968430          0.008230
# 570      6.930000e-07    -6.930000e-07   137.137607          0.000053
# 4897     1.194000e-02    -1.194000e-02   136.373100          0.019000
# 625      1.250000e-06    -1.250000e-06   133.850441          0.000978
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6080         -0.014300  ...            -286      3.805           0.390
# 3001         -0.008230  ...             -72      4.083           0.368
# 570          -0.000053  ...            -159      4.462           0.098
# 4897         -0.019000  ...            -146      4.456           0.102
# 625          -0.000978  ...            -167      3.975           0.259
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6080          -0.130     2.730          0.535         -1.248  289.23080
# 3001          -0.092     1.453          0.218         -0.510  293.52756
# 570           -0.182     0.897          0.238         -0.119  282.79764
# 4897          -0.361     0.867          0.448         -0.103  297.65436
# 625           -0.111     1.851          0.383         -0.575  288.90253
#
#             dec  koi_kepmag
# 6080  44.412483      13.054
# 3001  41.111439      15.162
# 570   43.578129      14.212
# 4897  43.178551      15.202
# 625   44.632992      12.953
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from keras.callbacks import EarlyStopping
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
y_train_categorical.shape
# Out:
# (5243, 3)

# %% [markdown]
# ## Creating Deep Learning Model

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=40))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=3, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               4100
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 14,503
# Trainable params: 14,503
# Non-trainable params: 0
# _________________________________________________________________

# %%
# from keras.callbacks import EarlyStopping

callbacks=[EarlyStopping(monitor='val_loss', patience=2)]

model.fit(
    X_train_scaled,
    y_train_categorical,
    callbacks=callbacks,
    epochs=60,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/60
# 164/164 - 1s - loss: 0.5387 - accuracy: 0.7418
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/60
# 164/164 - 0s - loss: 0.3728 - accuracy: 0.8047
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/60
# 164/164 - 0s - loss: 0.3565 - accuracy: 0.8167
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 4/60
# 164/164 - 0s - loss: 0.3501 - accuracy: 0.8255
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 5/60
# 164/164 - 0s - loss: 0.3385 - accuracy: 0.8367
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 6/60
# 164/164 - 0s - loss: 0.3398 - accuracy: 0.8371
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 7/60
# 164/164 - 0s - loss: 0.3273 - accuracy: 0.8444
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 8/60
# 164/164 - 0s - loss: 0.3230 - accuracy: 0.8451
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 9/60
# 164/164 - 0s - loss: 0.3232 - accuracy: 0.8531
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 10/60
# 164/164 - 0s - loss: 0.3178 - accuracy: 0.8543
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 11/60
# 164/164 - 0s - loss: 0.3143 - accuracy: 0.8629
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 12/60
# 164/164 - 0s - loss: 0.3138 - accuracy: 0.8543
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 13/60
# 164/164 - 0s - loss: 0.3064 - accuracy: 0.8610
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 14/60
# 164/164 - 0s - loss: 0.3054 - accuracy: 0.8644
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 15/60
# 164/164 - 0s - loss: 0.3079 - accuracy: 0.8589
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 16/60
# 164/164 - 0s - loss: 0.2974 - accuracy: 0.8678
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 17/60
# 164/164 - 0s - loss: 0.2973 - accuracy: 0.8676
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 18/60
# 164/164 - 0s - loss: 0.2959 - accuracy: 0.8678
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 19/60
# 164/164 - 0s - loss: 0.2909 - accuracy: 0.8793
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 20/60
# 164/164 - 0s - loss: 0.2940 - accuracy: 0.8682
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 21/60
# 164/164 - 0s - loss: 0.2898 - accuracy: 0.8724
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 22/60
# 164/164 - 0s - loss: 0.2833 - accuracy: 0.8779
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 23/60
# 164/164 - 0s - loss: 0.2825 - accuracy: 0.8762
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 24/60
# 164/164 - 0s - loss: 0.2823 - accuracy: 0.8762
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 25/60
# 164/164 - 0s - loss: 0.2791 - accuracy: 0.8816
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 26/60
# 164/164 - 0s - loss: 0.2760 - accuracy: 0.8808
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 27/60
# 164/164 - 0s - loss: 0.2762 - accuracy: 0.8804
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 28/60
# 164/164 - 0s - loss: 0.2829 - accuracy: 0.8772
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 29/60
# 164/164 - 0s - loss: 0.2792 - accuracy: 0.8734
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 30/60
# 164/164 - 0s - loss: 0.2748 - accuracy: 0.8796
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 31/60
# 164/164 - 0s - loss: 0.2742 - accuracy: 0.8804
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 32/60
# 164/164 - 0s - loss: 0.2700 - accuracy: 0.8842
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 33/60
# 164/164 - 0s - loss: 0.2705 - accuracy: 0.8798
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 34/60
# 164/164 - 0s - loss: 0.2715 - accuracy: 0.8835
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 35/60
# 164/164 - 0s - loss: 0.2730 - accuracy: 0.8812
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 36/60
# 164/164 - 0s - loss: 0.2667 - accuracy: 0.8844
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 37/60
# 164/164 - 0s - loss: 0.2674 - accuracy: 0.8808
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 38/60
# 164/164 - 0s - loss: 0.2618 - accuracy: 0.8852
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 39/60
# 164/164 - 0s - loss: 0.2592 - accuracy: 0.8898
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 40/60
# 164/164 - 0s - loss: 0.2635 - accuracy: 0.8880
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 41/60
# 164/164 - 0s - loss: 0.2680 - accuracy: 0.8812
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 42/60
# 164/164 - 0s - loss: 0.2602 - accuracy: 0.8842
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 43/60
# 164/164 - 0s - loss: 0.2615 - accuracy: 0.8838
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 44/60
# 164/164 - 0s - loss: 0.2586 - accuracy: 0.8879
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 45/60
# 164/164 - 0s - loss: 0.2531 - accuracy: 0.8909
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 46/60
# 164/164 - 0s - loss: 0.2551 - accuracy: 0.8873
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 47/60
# 164/164 - 0s - loss: 0.2497 - accuracy: 0.8899
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 48/60
# 164/164 - 0s - loss: 0.2547 - accuracy: 0.8858
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 49/60
# 164/164 - 0s - loss: 0.2526 - accuracy: 0.8869
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 50/60
# 164/164 - 0s - loss: 0.2525 - accuracy: 0.8892
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 51/60
# 164/164 - 0s - loss: 0.2498 - accuracy: 0.8905
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 52/60
# 164/164 - 0s - loss: 0.2581 - accuracy: 0.8882
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 53/60
# 164/164 - 0s - loss: 0.2510 - accuracy: 0.8850
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 54/60
# 164/164 - 0s - loss: 0.2467 - accuracy: 0.8936
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 55/60
# 164/164 - 0s - loss: 0.2437 - accuracy: 0.8915
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 56/60
# 164/164 - 0s - loss: 0.2492 - accuracy: 0.8905
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 57/60
# 164/164 - 0s - loss: 0.2469 - accuracy: 0.8934
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 58/60
# 164/164 - 0s - loss: 0.2455 - accuracy: 0.8949
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 59/60
# 164/164 - 0s - loss: 0.2484 - accuracy: 0.8915
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 60/60
# 164/164 - 0s - loss: 0.2445 - accuracy: 0.8966
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2436 - accuracy: 0.8919
# Normal Neural Network - Loss: 0.24359945952892303, Accuracy: 0.8918764591217041

# %% [markdown]
# ## Make Predictions

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:5])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:5])}")
# Out:
# Predicted classes: ['CANDIDATE' 'False_Positive' 'False_Positive' 'False_Positive'
#  'CANDIDATE']
# Actual Labels: ['CANDIDATE', 'False_Positive', 'False_Positive', 'False_Positive', 'CANDIDATE']

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'deep_learning.sav'
joblib.dump(model, filename)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-59b46ee81ede> in <module>
#       5 import joblib
#       6 filename = 'deep_learning.sav'
# ----> 7 joblib.dump(model, filename)
#
# /opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     478     elif is_filename:
#     479         with open(filename, 'wb') as f:
# --> 480             NumpyPickler(f, protocol=protocol).dump(value)
#     481     else:
#     482         NumpyPickler(filename, protocol=protocol).dump(value)
#
# /opt/anaconda3/lib/python3.8/pickle.py in dump(self, obj)
#     483         if self.proto >= 4:
#     484             self.framer.start_framing()
# --> 485         self.save(obj)
#     486         self.write(STOP)
#     487         self.framer.end_framing()
#
# /opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# /opt/anaconda3/lib/python3.8/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# /opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# /opt/anaconda3/lib/python3.8/pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# /opt/anaconda3/lib/python3.8/pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# /opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# /opt/anaconda3/lib/python3.8/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# /opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# /opt/anaconda3/lib/python3.8/pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# /opt/anaconda3/lib/python3.8/pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# /opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# /opt/anaconda3/lib/python3.8/pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# /opt/anaconda3/lib/python3.8/pickle.py in _batch_setitems(self, items)
#     992                 write(MARK)
#     993                 for k, v in tmp:
# --> 994                     save(k)
#     995                     save(v)
#     996                 write(SETITEMS)
#
# /opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     574                 reduce = getattr(obj, "__reduce_ex__", None)
#     575                 if reduce is not None:
# --> 576                     rv = reduce(self.proto)
#     577                 else:
#     578                     reduce = getattr(obj, "__reduce__", None)
#
# TypeError: cannot pickle 'weakref' object

# %%
# from keras.models import load_model

model.save('deep_learning.h5')
